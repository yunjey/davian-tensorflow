# %%
import tensorflow as tf

# session for jupyter notebook
sess = tf.InteractiveSession()

# %%
print tf.add(1, 2).eval()
# Out:
# 3

# %%
print tf.sub(3, 4).eval()
# Out:
# -1

# %%
print tf.mul(2, 3).eval()
# Out:
# 6

# %%
print tf.div(6, 5).eval()
# Out:
# 1

# %%
print tf.mod(5, 3).eval()
# Out:
# 2

# %%
print tf.pow(3, 2).eval()
# Out:
# 9

# %%
# syntax sugar
print sess.run(tf.less(1, 2))
# Out:
# True

# %%
print sess.run(tf.less_equal(1, 1))
# Out:
# True

# %%
print sess.run(tf.greater(1, 2))
# Out:
# False

# %%
print sess.run(tf.greater_equal(1, 2))
# Out:
# False
